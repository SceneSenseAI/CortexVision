# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # encoders:<br>
# sentiment analysis, classification, searchinng , info retreival RAG

# %% [markdown]
# # Decoders:<br>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Decoder info generation token wise

# %% [markdown]
# decoders use MASKED ATTENTION. : ti cant see ti+1....and so on<br>
# encoders use UNMASKED ATTENTION

# %%
from transformers import pipeline   # pipeline does model Load , Process , Run, Infer, Return all
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import requests
from io import BytesIO

# %%
pipeline =pipeline(task="image-segmentation",model="nvidia/segformer-b0-finetuned-ade-512-512")
#pass the image now
result=pipeline("https://huggingface.co/datasets/huggingface/documentation-images/resolve/main/pipeline-cat-chonk.jpeg")
# Out:
# Loading weights:   0%|          | 0/208 [00:00<?, ?it/s]

# %%
url="https://huggingface.co/datasets/huggingface/documentation-images/resolve/main/pipeline-cat-chonk.jpeg"
response = requests.get(url)# response of the request put on the server
image = Image.open(BytesIO(response.content))   # image opened via BytesIO
#response.content is just RAW BYTES
# these are wrappeed by BytesIO
#BytesIO wraps bytes and pretends they are a file.
image.show()# image displayed

# %%
image.size
# Out:
# (960, 686)

# %%
type(result)
# Out:
# list

# %%
len(result)
# Out:
# 6

# %%
result[0]
# Out:
# {'score': None,
#  'label': 'wall',
#  'mask': <PIL.Image.Image image mode=L size=960x686>}

# %%
result[1]
# Out:
# {'score': None,
#  'label': 'building',
#  'mask': <PIL.Image.Image image mode=L size=960x686>}

# %%
result[2]
# Out:
# {'score': None,
#  'label': 'person',
#  'mask': <PIL.Image.Image image mode=L size=960x686>}

# %%
result[3]
# Out:
# {'score': None,
#  'label': 'earth',
#  'mask': <PIL.Image.Image image mode=L size=960x686>}

# %%
result[4]
# Out:
# {'score': None,
#  'label': 'fence',
#  'mask': <PIL.Image.Image image mode=L size=960x686>}

# %%
result[5]
# Out:
# {'score': None,
#  'label': 'animal',
#  'mask': <PIL.Image.Image image mode=L size=960x686>}

# %%
type(result[2])
# Out:
# dict

# %%
type(result[2].keys())
# Out:
# dict_keys

# %%
labels=list(result[2].keys())

# %%
labels[2]
# Out:
# 'mask'

# %%
mask=result[2]["mask"]

# %%
mask.show()

# %% [markdown]
# ## result is a list of dictionaries and masks are the orginal PIL images with labels

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Image Segmentaion

# %% [markdown]
# ### classification (gives class but no location) -> <br>
# ### Object Detection (rough location) -><br>
# ### segmentation (pixel membership map) :<br>
# #### semantic segmentation (label for each pixel), instance segmentation (diff labels for diff class)<br>
# ### ViT is a ENCODER only architecture and we put a DECODER HEAD which generates a segmentation map

# %% [markdown]
# SEGFORMER = ViT + Decoder Head

# %% [markdown]
# # Depth Estimation

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Image -> encoder -> depth decoder -> depth values

# %% [markdown]
# <span style="color:red"> Pipeline is <B>very high level</b> and very automated, AutoModel is <B>LOW LEVEL</B></span>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # white== 255 ==1(scaled)
